# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import preprocess as prp
from metrics import (
    recall_at_k
)
import methods.g_top_k as g_top_k
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
evals = g_top_k.eval_for_given_sample(0.1)

# %%
sns.jointplot(
    data=evals,
    x='explore_coeff',
    y='recall_at_10',
    kind='hex'
)

# %%
np.corrcoef(evals.explore_coeff, evals.recall_at_10)
# Out:
# array([[ 1.        , -0.11163861],
#        [-0.11163861,  1.        ]])

# %%
g_top_k.main()
# Out:
# Sample ratio: 0.1
# explore_coeff: 0.411 +/- 0.307
# recall_at_5: 0.049 +/- 0.097
# Correlation with explore_coeff: -0.127
# recall_at_10: 0.073 +/- 0.118
# Correlation with explore_coeff: -0.129
# recall_at_20: 0.101 +/- 0.140
# Correlation with explore_coeff: -0.124
# ----------------------------------------------------------------------------------------------------
# Sample ratio: 0.15
# explore_coeff: 0.414 +/- 0.307
# recall_at_5: 0.047 +/- 0.095
# Correlation with explore_coeff: -0.139
# recall_at_10: 0.071 +/- 0.115
# Correlation with explore_coeff: -0.131
# recall_at_20: 0.099 +/- 0.140
# Correlation with explore_coeff: -0.131
# ----------------------------------------------------------------------------------------------------
# Sample ratio: 0.2
# explore_coeff: 0.411 +/- 0.306
# recall_at_5: 0.047 +/- 0.093
# Correlation with explore_coeff: -0.133
# recall_at_10: 0.070 +/- 0.113
# Correlation with explore_coeff: -0.132
# recall_at_20: 0.098 +/- 0.136
# ...
